# %% [markdown]
# # 2. Теорема о конечных приращениях (Теорема Лагранжа)

# %% [markdown]
# **Теорема Лагранжа.**  Если функция $f(x)$ непрерывна на отрезке $[a, b]$ и дифференцируема во всех внутренних точках этого отреза, то внутри отреза $[a, b]$ найдется по крайней мере одна точка $c$, $a < c < b$, что
#
# $$f(b) - f(a) = f'(c)(b-a). \tag{1}$$

# %% [markdown]
# **Доказательство.** Обозначим буквой $Q$ число $\frac{f(b)-f(a)}{b - a}$ т.е. положим
#
# $$Q = \frac{f(b) - f(a)}{b - a} \tag{2}$$
#
# и рассмотрим вспомогательную функцию $F(x)$, определенную равенством
#
# $$F(x) = f(x) - f(a) - (x-a) \ Q. \tag{3}$$
#
# Выясним геометрический смысл функции $F(x)$. Для этого напишем сначала уравнение хорды $AB$ см рис.
#
#
# <div align="center">
#   <img src="95.png" alt="alt text" width="250">
# </div>
#
# учитывая, что ее угловой коэффициент равен $\frac{f(b) - f(a)}{b - a} = Q$ и что она проходит через точку $(a; f(a)):$
#
# $$y - f(a) = Q(x - a)$$
#
# $$y = f(a) + Q(x - a)$$
#
# Но $F(x) = f(x)- [f(a) + Q(x - a)]$. Следовательно, $F(x) ждя каждого значения $x$ равняется разности ординат кривой $y = f(x)$ и хорды $y = f(a) + Q(x-a)$ для точек с одинаковой абсциссой
#
# Легко видеть, что $F(x)$ непрерывна на отрезке $[a, b]$ дифференируема внутри этого отрезка и обращается в нуль на концах отрезка, т.е. $F(a) = 0, F(b) = 0$. Следовательно, к функции $F(x)$ применима теорема Ролля. СОгласно этой теореме внутри отрезка существует точка $x=c$ такая, что $F'(c) = 0$. Но $F'(x) = f'(x) - Q$. Значит, $F'(c) = f'(c) - Q = 0$, откуда  $Q = f'(c)$
#
# Подставляя значение  $Q$ в равенство (2), будем иметь:
#
# $$\frac{f(b) - f(a)}{b - a} = f'(c),$$
#
# откуда непосредственно следует формула  (1). Таким образом, теорема доказана.
#
# Чтобы выяснить геометрический смысл теоремы Лагранжа, обратимся к рис. ниже
#
# <div align="center">
#   <img src="95.png" alt="alt text" width="250">
# </div>
#
# Здесь величина $\frac{f(b)-f(a)}{b-a}$ представляет собой тангенс угла $\alpha$ наклона хорды, проходящей через точки $A$ и $B$ графика с абс
