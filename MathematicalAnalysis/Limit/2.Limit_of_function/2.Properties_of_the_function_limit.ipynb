# %% [markdown]
# ### $\S \ 2.$  Limit of a Function
# #### 2. Properties of the function limit
#
# We now establish several frequently used properties of the limit of a function, many of which are to the properties
