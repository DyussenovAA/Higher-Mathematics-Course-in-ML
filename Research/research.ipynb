# %% [markdown]
# **Тема. Энтропия и информация (рук. С.Н.Поздняков)**
#
# по книге А.М.Яглом, И.М.Яглом “Вероятность и информация”
# Задание: обоим изучить первые две главы,
#
# потом разделиться:
# Первая часть задания (на 1-го члена команды):
# Решение логических задач с помощью теории информации (глава 3).
#
#
# Вторая часть (на 2-го члена команды):
# “Передача сообщений по линиям связи” (глава 4)
# (работа для команды из 2 человек).
